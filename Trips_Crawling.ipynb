# %% [markdown]
# # **파이썬 웹 스크리핑**
# 트립닷컴 사이트의 지역별 가볼만한 곳 TOP 20 데이터를 가져와 보았다.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %%
# https://kr.trip.com/toplist/tripbest/seoul-best-things-to-do-100200187047/?locale=ko-KR&curr=KRW - 서울
# https://kr.trip.com/toplist/tripbest/incheon-best-things-to-do-100200213450/?locale=ko-KR&curr=KRW - 인천
# https://kr.trip.com/toplist/tripbest/busan-best-things-to-do-100000009409/?locale=ko-KR&curr=KRW - 부산
# https://kr.trip.com/toplist/tripbest/jeju-best-things-to-do-100000012168/?locale=ko-KR&curr=KRW - 제주

# %%
# url 확인
url = "https://kr.trip.com/toplist/tripbest/incheon-best-things-to-do-100000026828/"
response = requests.get(url)

# %%
# 접속 상태 확인
response.raise_for_status()

# %%
# html / lxml 로 불러오기
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# 태그 확인
print(soup.title)
# Out:
# <title>2023 인천 가볼만한곳 베스트 20</title>

# %%
# 개발자 옵션을 통해 원하는 텍스트 데이터 추출해보기
Text_Target = soup.find("h2", attrs={"class":"HotelItemTitleText-sc-9lfuiu-7 cqmoRq"})
print(Text_Target)
# Out:
# <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/wolmido-10559326/?rankingId=100000026828" title="월미도 인기 명소">월미도<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>

# %%
# 텍스트 데이터 불러오기
Text_Target.a.get_text()
# Out:
# '월미도'

# %%
# .text로도 확인
print(Text_Target.a.text)
# Out:
# 월미도

# %%
# find_all 함수를 통해 태그 제목에 공통으로 되어있는 HotelItemTitleText 값으로 텍스트 검색
All_Text_Target = soup.find_all("h2", class_=re.compile(r'^HotelItemTitleText'))
All_Text_Target
# Out:
# [<h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/wolmido-10559326/?rankingId=100000026828" title="월미도 인기 명소">월미도<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>,
#  <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/chinatown-incheon-96550/?rankingId=100000026828" title="인천 차이나타운 인기 명소">인천 차이나타운<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>,
#  <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/incheon-international-airport-65176733/?rankingId=100000026828" title="인천국제공항 인기 명소">인천국제공항<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>,
#  <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/songdo-central-park-90331/?rankingId=100000026828" title="송도 센트럴파크 인기 명소">송도 센트럴파크<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>,
#  <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/sinpo-international-market-incheon-142830425/?rankingId=100000026828" title="Sinpo International Market, Incheon 인기 명소">Sinpo International Market, Incheon<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>,
#  <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/freedom-park-10559325/?rankingId=100000026828" title="자유공원 인기 명소">자유공원<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>,
#  <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/aramaru-skywalk-142593189/?rankingId=100000026828" title="AraMaru Skywalk 인기 명소">AraMaru Skywalk<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>,
#  <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/songwol-dong-fairy-tale-village-28447997/?rankingId=100000026828" title="송월동 동화마을 인기 명소">송월동 동화마을<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>,
#  <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/cgv-incheon-142735918/?rankingId=100000026828" title="CGV Incheon 인기 명소">CGV Incheon<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>,
#  <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/shingi-market-142896139/?rankingId=100000026828" title="Shingi Market 인기 명소">Shingi Market<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>,
#  <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/incheon-bridge-13640848/?rankingId=100000026828" title="인천대교 인기 명소">인천대교<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>,
#  <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/my-land-141095092/?rankingId=100000026828" title="마이랜드 인기 명소">마이랜드<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>,
#  <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/memorial-hall-for-incheon-landing-operation-10559587/?rankingId=100000026828" title="인천상륙작전기념관 인기 명소">인천상륙작전기념관<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>,
#  <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/angel-rock-22864863/?rankingId=100000026828" title="선녀바위 인기 명소">선녀바위<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>,
#  <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/cgv-142311708/?rankingId=100000026828" title="CGV 인천연수 인기 명소">CGV 인천연수<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>,
#  <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/incheon-national-university-songdo-campus-10794359/?rankingId=100000026828" title="인천대학교 송도캠퍼스 인기 명소">인천대학교 송도캠퍼스<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>,
#  <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/megabox-songdo-141870744/?rankingId=100000026828" title="메가박스 송도 인기 명소">메가박스 송도<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>,
#  <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/lotte-cinema-incheon-asiad-141244826/?rankingId=100000026828" title="롯데시네마 인천아시아드 인기 명소">롯데시네마 인천아시아드<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>,
#  <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/cgv-gyeyang-142458271/?rankingId=100000026828" title="CGV Gyeyang 인기 명소">CGV Gyeyang<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>,
#  <h2 class="HotelItemTitleText-sc-9lfuiu-7 cqmoRq"><a href="https://kr.trip.com/travel-guide/attraction/incheon/ara-canal-sicheon-garam-place-138399115/?rankingId=100000026828" title="경인아라뱃길 시천가람터 인기 명소">경인아라뱃길 시천가람터<div class="HotelItemRate-sc-9lfuiu-9 fKQgWX"></div></a></h2>]

# %%
# TOP20 리스트 저장
taget_list = []
for tag in All_Text_Target :
    taget_list.append(tag.text)
taget_list
# Out:
# ['월미도',
#  '인천 차이나타운',
#  '인천국제공항',
#  '송도 센트럴파크',
#  'Sinpo International Market, Incheon',
#  '자유공원',
#  'AraMaru Skywalk',
#  '송월동 동화마을',
#  'CGV Incheon',
#  'Shingi Market',
#  '인천대교',
#  '마이랜드',
#  '인천상륙작전기념관',
#  '선녀바위',
#  'CGV 인천연수',
#  '인천대학교 송도캠퍼스',
#  '메가박스 송도',
#  '롯데시네마 인천아시아드',
#  'CGV Gyeyang',
#  '경인아라뱃길 시천가람터']

# %%
# 인천 페이지의 TOP 20 스크리핑
Sample_Crawling = pd.DataFrame({'인천':taget_list})
Sample_Crawling
# Out:
#                                      인천
# 0                                   월미도
# 1                              인천 차이나타운
# 2                                인천국제공항
# 3                              송도 센트럴파크
# 4   Sinpo International Market, Incheon
# 5                                  자유공원
# 6                       AraMaru Skywalk
# 7                              송월동 동화마을
# 8                           CGV Incheon
# 9                         Shingi Market
# 10                                 인천대교
# 11                                 마이랜드
# 12                            인천상륙작전기념관
# 13                                 선녀바위
# 14                             CGV 인천연수
# 15                          인천대학교 송도캠퍼스
# 16                              메가박스 송도
# 17                         롯데시네마 인천아시아드
# 18                          CGV Gyeyang
# 19                         경인아라뱃길 시천가람터

# %% [markdown]
# ### 인천, 서울, 제주, 부산 가 볼 만한 곳 TOP 20 스크리핑

# %%
# 각각의 URL 저장
urls = [
    "https://kr.trip.com/toplist/tripbest/seoul-best-things-to-do-100000001628/?locale=ko-KR&curr=KRW",
    "https://kr.trip.com/toplist/tripbest/incheon-best-things-to-do-100000026828/?locale=ko-KR&curr=KRW",
    "https://kr.trip.com/toplist/tripbest/busan-best-things-to-do-100000009409/?locale=ko-KR&curr=KRW",
    "https://kr.trip.com/toplist/tripbest/jeju-best-things-to-do-100000012168/?locale=ko-KR&curr=KRW"
]

# %%
# DataFrame 에 저장할 데이터 딕셔너리로 저장
Frame_Dic = {}
for url in urls:
    # 딕셔너리 key 값
    City = url.split("/")[-2].split('-')[0]
    # URL 요청
    response = requests.get(url)
    response.raise_for_status()
    soup = BeautifulSoup(response.text, 'html.parser')
    # 공통된 태그 제목으로 검색
    All_Text_Target = soup.find_all("h2", class_=re.compile(r'^HotelItemTitleText'))
    # 딕셔너리 value 값 저장을 위한 리스트 생성
    taget_list = []
    # TOP 1 ~ 20 까지 리스트에 저장
    for tag in All_Text_Target :
        taget_list.append(tag.text)
   # 지역별 Key : Value 값 저장
    Frame_Dic[City] = taget_list
# 저장된 딕셔너리를 통해 데이터 프레임 생성
Trip_Crawling = pd.DataFrame(Frame_Dic)
# Out:
# seoul
# ['N서울타워', '명동', '경복궁', '북촌 한옥마을', '명동난타', '코엑스 아쿠아리움', '청계천', '이화여자대학교', '남산 공원', '청와대', '광장시장', '인사동', 'DDP 동대문디자인플라자', '이태원동', '삼청동', '페인터즈 (명보아트홀)', '홍익대학교 서울캠퍼스', '롯데월드', '63빌딩', '별마당 도서관']
# {'seoul': ['N서울타워', '명동', '경복궁', '북촌 한옥마을', '명동난타', '코엑스 아쿠아리움', '청계천', '이화여자대학교', '남산 공원', '청와대', '광장시장', '인사동', 'DDP 동대문디자인플라자', '이태원동', '삼청동', '페인터즈 (명보아트홀)', '홍익대학교 서울캠퍼스', '롯데월드', '63빌딩', '별마당 도서관']}
# incheon
# ['월미도', '인천 차이나타운', '인천국제공항', '송도 센트럴파크', 'Sinpo International Market, Incheon', '자유공원', 'AraMaru Skywalk', '송월동 동화마을', 'CGV Incheon', 'Shingi Market', '인천대교', '마이랜드', '인천상륙작전기념관', '선녀바위', 'CGV 인천연수', '인천대학교 송도캠퍼스', '메가박스 송도', '롯데시네마 인천아시아드', 'CGV Gyeyang', '경인아라뱃길 시천가람터']
# {'seoul': ['N서울타워', '명동', '경복궁', '북촌 한옥마을', '명동난타', '코엑스 아쿠아리움', '청계천', '이화여자대학교', '남산 공원', '청와대', '광장시장', '인사동', 'DDP 동대문디자인플라자', '이태원동', '삼청동', '페인터즈 (명보아트홀)', '홍익대학교 서울캠퍼스', '롯데월드', '63빌딩', '별마당 도서관'], 'incheon': ['월미도', '인천 차이나타운', '인천국제공항', '송도 센트럴파크', 'Sinpo International Market, Incheon', '자유공원', 'AraMaru Skywalk', '송월동 동화마을', 'CGV Incheon', 'Shingi Market', '인천대교', '마이랜드', '인천상륙작전기념관', '선녀바위', 'CGV 인천연수', '인천대학교 송도캠퍼스', '메가박스 송도', '롯데시네마 인천아시아드', 'CGV Gyeyang', '경인아라뱃길 시천가람터']}
# busan
# ['감천문화마을', '해운대해수욕장', 'SEA LIFE 부산 아쿠아리움', '해동용궁사', '부산 광안리 해수욕장', '다이아몬드타워 (부산타워)', '남포동', '용두산공원', '태종대유원지', '광안대교', '송도해상케이블카 송도베이스테이션', 'BIFF광장', '서면역', '서면1번가', '오륙도', '동백공원', '범어사', '부산 차이나타운', '청사포', '송도구름산책로']
# {'seoul': ['N서울타워', '명동', '경복궁', '북촌 한옥마을', '명동난타', '코엑스 아쿠아리움', '청계천', '이화여자대학교', '남산 공원', '청와대', '광장시장', '인사동', 'DDP 동대문디자인플라자', '이태원동', '삼청동', '페인터즈 (명보아트홀)', '홍익대학교 서울캠퍼스', '롯데월드', '63빌딩', '별마당 도서관'], 'incheon': ['월미도', '인천 차이나타운', '인천국제공항', '송도 센트럴파크', 'Sinpo International Market, Incheon', '자유공원', 'AraMaru Skywalk', '송월동 동화마을', 'CGV Incheon', 'Shingi Market', '인천대교', '마이랜드', '인천상륙작전기념관', '선녀바위', 'CGV 인천연수', '인천대학교 송도캠퍼스', '메가박스 송도', '롯데시네마 인천아시아드', 'CGV Gyeyang', '경인아라뱃길 시천가람터'], 'busan': ['감천문화마을', '해운대해수욕장', 'SEA LIFE 부산 아쿠아리움', '해동용궁사', '부산 광안리 해수욕장', '다이아몬드타워 (부산타워)', '남포동', '용두산공원', '태종대유원지', '광안대교', '송도해상케이블카 송도베이스테이션', 'BIFF광장', '서면역', '서면1번가', '오륙도', '동백공원', '범어사', '부산 차이나타운', '청사포', '송도구름산책로']}
# jeju
# ['우도', '한라산 국립공원', '제주난타전용관', '용두암', '에코랜드', 'BAOJIAN STREET', '산굼부리', '월정리 갈비밥', '함덕해수욕장', '제주 러브랜드', '애월한담산책로', '올레길', '협재해변', '칠성로 쇼핑거리', '한라수목원', '흑돼지거리', '브릭캠퍼스 제주', '제주특별자치도 민속자연사박물관', '만장굴', '한림공원']
# {'seoul': ['N서울타워', '명동', '경복궁', '북촌 한옥마을', '명동난타', '코엑스 아쿠아리움', '청계천', '이화여자대학교', '남산 공원', '청와대', '광장시장', '인사동', 'DDP 동대문디자인플라자', '이태원동', '삼청동', '페인터즈 (명보아트홀)', '홍익대학교 서울캠퍼스', '롯데월드', '63빌딩', '별마당 도서관'], 'incheon': ['월미도', '인천 차이나타운', '인천국제공항', '송도 센트럴파크', 'Sinpo International Market, Incheon', '자유공원', 'AraMaru Skywalk', '송월동 동화마을', 'CGV Incheon', 'Shingi Market', '인천대교', '마이랜드', '인천상륙작전기념관', '선녀바위', 'CGV 인천연수', '인천대학교 송도캠퍼스', '메가박스 송도', '롯데시네마 인천아시아드', 'CGV Gyeyang', '경인아라뱃길 시천가람터'], 'busan': ['감천문화마을', '해운대해수욕장', 'SEA LIFE 부산 아쿠아리움', '해동용궁사', '부산 광안리 해수욕장', '다이아몬드타워 (부산타워)', '남포동', '용두산공원', '태종대유원지', '광안대교', '송도해상케이블카 송도베이스테이션', 'BIFF광장', '서면역', '서면1번가', '오륙도', '동백공원', '범어사', '부산 차이나타운', '청사포', '송도구름산책로'], 'jeju': ['우도', '한라산 국립공원', '제주난타전용관', '용두암', '에코랜드', 'BAOJIAN STREET', '산굼부리', '월정리 갈비밥', '함덕해수욕장', '제주 러브랜드', '애월한담산책로', '올레길', '협재해변', '칠성로 쇼핑거리', '한라수목원', '흑돼지거리', '브릭캠퍼스 제주', '제주특별자치도 민속자연사박물관', '만장굴', '한림공원']}

# %%
# 서울, 인천, 부산, 제주의 여행지 TOP 20
Trip_Crawling
# Out:
#             seoul                              incheon              busan  \
# 0           N서울타워                                  월미도             감천문화마을
# 1              명동                             인천 차이나타운            해운대해수욕장
# 2             경복궁                               인천국제공항  SEA LIFE 부산 아쿠아리움
# 3         북촌 한옥마을                             송도 센트럴파크              해동용궁사
# 4            명동난타  Sinpo International Market, Incheon        부산 광안리 해수욕장
# 5       코엑스 아쿠아리움                                 자유공원     다이아몬드타워 (부산타워)
# 6             청계천                      AraMaru Skywalk                남포동
# 7         이화여자대학교                             송월동 동화마을              용두산공원
# 8           남산 공원                          CGV Incheon             태종대유원지
# 9             청와대                        Shingi Market               광안대교
# 10           광장시장                                 인천대교  송도해상케이블카 송도베이스테이션
# 11            인사동                                 마이랜드             BIFF광장
# 12  DDP 동대문디자인플라자                            인천상륙작전기념관                서면역
# 13           이태원동                                 선녀바위              서면1번가
# 14            삼청동                             CGV 인천연수                오륙도
# 15   페인터즈 (명보아트홀)                          인천대학교 송도캠퍼스               동백공원
# 16    홍익대학교 서울캠퍼스                              메가박스 송도                범어사
# 17           롯데월드                         롯데시네마 인천아시아드           부산 차이나타운
# 18           63빌딩                          CGV Gyeyang                청사포
# 19        별마당 도서관                         경인아라뱃길 시천가람터            송도구름산책로
#
#                 jeju
# 0                 우도
# 1           한라산 국립공원
# 2            제주난타전용관
# 3                용두암
# 4               에코랜드
# 5     BAOJIAN STREET
# 6               산굼부리
# 7            월정리 갈비밥
# 8             함덕해수욕장
# 9            제주 러브랜드
# 10           애월한담산책로
# 11               올레길
# 12              협재해변
# 13          칠성로 쇼핑거리
# 14             한라수목원
# 15             흑돼지거리
# 16          브릭캠퍼스 제주
# 17  제주특별자치도 민속자연사박물관
# 18               만장굴
# 19              한림공원

# %%
# 인덱스 번호를 통해 순위 표기
Trip_Crawling.index = Trip_Crawling.index + 1
Trip_Crawling
# Out:
#             seoul                              incheon              busan  \
# 1           N서울타워                                  월미도             감천문화마을
# 2              명동                             인천 차이나타운            해운대해수욕장
# 3             경복궁                               인천국제공항  SEA LIFE 부산 아쿠아리움
# 4         북촌 한옥마을                             송도 센트럴파크              해동용궁사
# 5            명동난타  Sinpo International Market, Incheon        부산 광안리 해수욕장
# 6       코엑스 아쿠아리움                                 자유공원     다이아몬드타워 (부산타워)
# 7             청계천                      AraMaru Skywalk                남포동
# 8         이화여자대학교                             송월동 동화마을              용두산공원
# 9           남산 공원                          CGV Incheon             태종대유원지
# 10            청와대                        Shingi Market               광안대교
# 11           광장시장                                 인천대교  송도해상케이블카 송도베이스테이션
# 12            인사동                                 마이랜드             BIFF광장
# 13  DDP 동대문디자인플라자                            인천상륙작전기념관                서면역
# 14           이태원동                                 선녀바위              서면1번가
# 15            삼청동                             CGV 인천연수                오륙도
# 16   페인터즈 (명보아트홀)                          인천대학교 송도캠퍼스               동백공원
# 17    홍익대학교 서울캠퍼스                              메가박스 송도                범어사
# 18           롯데월드                         롯데시네마 인천아시아드           부산 차이나타운
# 19           63빌딩                          CGV Gyeyang                청사포
# 20        별마당 도서관                         경인아라뱃길 시천가람터            송도구름산책로
#
#                 jeju
# 1                 우도
# 2           한라산 국립공원
# 3            제주난타전용관
# 4                용두암
# 5               에코랜드
# 6     BAOJIAN STREET
# 7               산굼부리
# 8            월정리 갈비밥
# 9             함덕해수욕장
# 10           제주 러브랜드
# 11           애월한담산책로
# 12               올레길
# 13              협재해변
# 14          칠성로 쇼핑거리
# 15             한라수목원
# 16             흑돼지거리
# 17          브릭캠퍼스 제주
# 18  제주특별자치도 민속자연사박물관
# 19               만장굴
# 20              한림공원
